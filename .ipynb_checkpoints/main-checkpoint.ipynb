# %% [markdown]
# Credit for Code: https://www.kaggle.com/code/brsdincer/brain-tumor-prediction-new-data-full-explanation

# %% [markdown]
# Importing Libraries and ignoring warnings

# %% [markdown]
# Doubts:
#
# Batches -> Data batch and label batch -> what is it?
# Ask about image data generator
# ask about validation set

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from warnings import filterwarnings
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report, roc_auc_score, roc_curve
from tensorflow.keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, BatchNormalization,MaxPooling2D
from keras import models
from keras import layers
import tensorflow as tf
import os
import os.path
from pathlib import Path
import cv2
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.utils.np_utils import to_categorical
from sklearn.model_selection import train_test_split
from keras import regularizers
from tensorflow.keras.optimizers import RMSprop,Adam
import glob
from PIL import Image

# IGNORING UNNECESSARRY WARNINGS

filterwarnings("ignore",category=DeprecationWarning)
filterwarnings("ignore", category=FutureWarning) 
filterwarnings("ignore", category=UserWarning)

# %% [markdown]
# Organization of the Data

# %% [markdown]
# Training Set

# %%
#Training Set

No_DataPath = Path("brain-tumor-detection/no/")
Yes_DataPath = Path("brain-tumor-detection/yes/")

No_jpgList = list(No_DataPath.glob(r"*.jpg"))
Yes_jpgList = list(Yes_DataPath.glob(r"*.jpg"))

# %%
#Checking whether list works

print(No_jpgList[0:7])
print("-----------------------"*5)
print(Yes_jpgList[0:7])
# Out:
# [WindowsPath('brain-tumor-detection/no/no0.jpg'), WindowsPath('brain-tumor-detection/no/no1.jpg'), WindowsPath('brain-tumor-detection/no/no10.jpg'), WindowsPath('brain-tumor-detection/no/no100.jpg'), WindowsPath('brain-tumor-detection/no/no1000.jpg'), WindowsPath('brain-tumor-detection/no/no1001.jpg'), WindowsPath('brain-tumor-detection/no/no1002.jpg')]
# -------------------------------------------------------------------------------------------------------------------
# [WindowsPath('brain-tumor-detection/yes/y0.jpg'), WindowsPath('brain-tumor-detection/yes/y1.jpg'), WindowsPath('brain-tumor-detection/yes/y10.jpg'), WindowsPath('brain-tumor-detection/yes/y100.jpg'), WindowsPath('brain-tumor-detection/yes/y1000.jpg'), WindowsPath('brain-tumor-detection/yes/y1001.jpg'), WindowsPath('brain-tumor-detection/yes/y1002.jpg')]

# %%
#creating a list with both yes and no pictures

yn_List = []

for i in No_jpgList:
    yn_List.append(i)

for i in Yes_jpgList:
    yn_List.append(i)

print(yn_List[0:5])
# Out:
# [WindowsPath('brain-tumor-detection/no/no0.jpg'), WindowsPath('brain-tumor-detection/no/no1.jpg'), WindowsPath('brain-tumor-detection/no/no10.jpg'), WindowsPath('brain-tumor-detection/no/no100.jpg'), WindowsPath('brain-tumor-detection/no/no1000.jpg')]

# %%
#Creating a list of catagories for better organization

jpgCat = list(map(lambda x: os.path.split(os.path.split(x)[0])[1], yn_List))
print(jpgCat[0:10])
# Out:
# ['no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no']

# %%
#Creating Pandas Table

jpgPath_series = pd.Series(yn_List, name="JPG").astype(str)
jpgCat_series = pd.Series(jpgCat, name="Category")

TrainData = pd.concat([jpgPath_series, jpgCat_series], axis = 1)

#Shuffling the data
TrainData = TrainData.sample(frac = 1).reset_index(drop=True)

print(TrainData.head(-1))
# Out:
#                                       JPG Category
# 0      brain-tumor-detection\yes\y540.jpg      yes
# 1      brain-tumor-detection\no\no834.jpg       no
# 2      brain-tumor-detection\yes\y519.jpg      yes
# 3     brain-tumor-detection\no\no1330.jpg       no
# 4      brain-tumor-detection\no\no959.jpg       no
# ...                                   ...      ...
# 2994  brain-tumor-detection\yes\y1023.jpg      yes
# 2995  brain-tumor-detection\no\no1094.jpg       no
# 2996  brain-tumor-detection\no\no1497.jpg       no
# 2997   brain-tumor-detection\no\no436.jpg       no
# 2998  brain-tumor-detection\no\no1300.jpg       no
#
# [2999 rows x 2 columns]

# %% [markdown]
# Test Set

# %%
#Test Set
testPath = Path("brain-tumor-detection/pred/")
testJPG = list(testPath.glob(r"*.jpg"))

# %%
#Checking if list prints

print(testJPG[0:5])
# Out:
# [WindowsPath('brain-tumor-detection/pred/pred0.jpg'), WindowsPath('brain-tumor-detection/pred/pred1.jpg'), WindowsPath('brain-tumor-detection/pred/pred10.jpg'), WindowsPath('brain-tumor-detection/pred/pred11.jpg'), WindowsPath('brain-tumor-detection/pred/pred12.jpg')]

# %%
#Creating a list of labels for test set

testLabels = list(map(lambda x: os.path.split(os.path.split(x)[0])[1],testJPG))
print(testLabels[0:5])
# Out:
# ['pred', 'pred', 'pred', 'pred', 'pred']

# %%
testJPG_Series = pd.Series(testJPG, name = "JPG").astype(str)
testLabels_Series = pd.Series(testLabels, name = "Category")

testData = pd.concat([testJPG_Series, testLabels_Series], axis=1)
print(testData.head())
# Out:
#                                      JPG Category
# 0   brain-tumor-detection\pred\pred0.jpg     pred
# 1   brain-tumor-detection\pred\pred1.jpg     pred
# 2  brain-tumor-detection\pred\pred10.jpg     pred
# 3  brain-tumor-detection\pred\pred11.jpg     pred
# 4  brain-tumor-detection\pred\pred12.jpg     pred

# %% [markdown]
# Visualizaing in the form of Images

# %%
img = plt.figure(figsize=(10, 10))
plt.imshow(plt.imread(TrainData["JPG"][10]))
plt.title(TrainData["Category"][10])
# Out:
# Text(0.5, 1.0, 'no')

# %%
fig, axes = plt.subplots(nrows = 5, ncols = 5, figsize=(10,10),subplot_kw ={'xticks':[], 'yticks':[]})

for i, ax in enumerate(axes.flat):
    ax.imshow(plt.imread(TrainData["JPG"][i]))
    ax.set_title(TrainData["Category"][i])

plt.tight_layout()
plt.show()

# %%
train_data, test_data = train_test_split(TrainData, train_size=0.8, random_state=42)
print(train_data.shape)
print(train_data.head(-1))
print("--------------"*8)
print(test_data.shape)
# Out:
# (2400, 2)
#                                       JPG Category
# 642    brain-tumor-detection\no\no509.jpg       no
# 700   brain-tumor-detection\yes\y1066.jpg      yes
# 226    brain-tumor-detection\no\no467.jpg       no
# 1697   brain-tumor-detection\no\no432.jpg       no
# 1010   brain-tumor-detection\no\no954.jpg       no
# ...                                   ...      ...
# 2169   brain-tumor-detection\yes\y116.jpg      yes
# 1638   brain-tumor-detection\no\no206.jpg       no
# 1095  brain-tumor-detection\no\no1091.jpg       no
# 1130   brain-tumor-detection\no\no159.jpg       no
# 1294   brain-tumor-detection\no\no773.jpg       no
#
# [2399 rows x 2 columns]
# ----------------------------------------------------------------------------------------------------------------
# (600, 2)

# %% [markdown]
# Image Data Generator

# %%
from cv2 import batchDistance


Generator = ImageDataGenerator(rescale=1./255, validation_split=0.1)

Train_Set = Generator.flow_from_dataframe(dataframe=train_data,
                                               x_col="JPG",
                                               y_col="Category",
                                               color_mode="grayscale",
                                               class_mode="categorical",
                                               subset="training",
                                               batch_size=20,
                                               target_size=(200,200))

Validation_Set = Generator.flow_from_dataframe(dataframe=train_data,
                                                     x_col="JPG",
                                                     y_col="Category",
                                                     color_mode="grayscale",
                                                     class_mode="categorical",
                                                     subset="validation",
                                                     batch_size=20,
                                                     target_size=(200,200))


Test_Set = Generator.flow_from_dataframe(dataframe=test_data,
                                              x_col="JPG",
                                              y_col="Category",
                                              color_mode="grayscale",
                                              class_mode="categorical",
                                              batch_size=20,
                                              target_size=(200,200))
# Out:
# Found 2160 validated image filenames belonging to 2 classes.
# Found 240 validated image filenames belonging to 2 classes.
# Found 600 validated image filenames belonging to 2 classes.

# %%
for i,j in Train_Set:
    print(i.shape)
    print(j.shape)
    break
# Out:
# (20, 200, 200, 1)
# (20, 2)

# %% [markdown]
# # CNN MODEL FOR NON-DIVERSIFICATION

# %% [markdown]
# ### MODEL STRUCTURE

# %%
Model = Sequential()

Model.add(Conv2D(32,(5,5),activation="relu",input_shape=(200,200,1)))
Model.add(MaxPool2D((2,2)))
Model.add(Dropout(0.2))
#
Model.add(Conv2D(64,(3,3),activation="relu"))
Model.add(MaxPool2D((2,2)))
Model.add(Dropout(0.2))
#
Model.add(Conv2D(128,(3,3),activation="relu"))
Model.add(MaxPool2D((2,2)))
Model.add(Dropout(0.2))
#
Model.add(Conv2D(256,(3,3),activation="relu"))
Model.add(MaxPool2D((2,2)))
Model.add(Dropout(0.2))
#
Model.add(Flatten())
Model.add(Dropout(0.5))
Model.add(Dense(512,activation="relu"))
Model.add(Dense(2,activation="softmax"))

# %% [markdown]
# ## Model Compile

# %%
Model.compile(optimizer=RMSprop(lr=0.001),loss="categorical_crossentropy",metrics=["accuracy"])

# %%
ANN_Model = Model.fit(Train_Set,validation_data=Validation_Set,
                      epochs=30,steps_per_epoch=60)
# Out:
# Epoch 1/30
# 60/60 [==============================] - 48s 763ms/step - loss: 0.8306 - accuracy: 0.6933 - val_loss: 0.5612 - val_accuracy: 0.7375
# Epoch 2/30
# 60/60 [==============================] - 57s 951ms/step - loss: 0.5432 - accuracy: 0.7450 - val_loss: 0.4774 - val_accuracy: 0.7958
# Epoch 3/30
# 60/60 [==============================] - 54s 890ms/step - loss: 0.4523 - accuracy: 0.8058 - val_loss: 0.3599 - val_accuracy: 0.8542
# Epoch 4/30
# 60/60 [==============================] - 52s 863ms/step - loss: 0.3821 - accuracy: 0.8458 - val_loss: 0.2743 - val_accuracy: 0.8667
# Epoch 5/30
# 60/60 [==============================] - 62s 1s/step - loss: 0.3314 - accuracy: 0.8608 - val_loss: 0.2458 - val_accuracy: 0.9083
# Epoch 6/30
# 60/60 [==============================] - 54s 898ms/step - loss: 0.2881 - accuracy: 0.8850 - val_loss: 0.2440 - val_accuracy: 0.9042
# Epoch 7/30
# 60/60 [==============================] - 51s 855ms/step - loss: 0.2648 - accuracy: 0.8992 - val_loss: 0.2359 - val_accuracy: 0.9167
# Epoch 8/30
# 60/60 [==============================] - 47s 787ms/step - loss: 0.2494 - accuracy: 0.9033 - val_loss: 0.2668 - val_accuracy: 0.8917
# Epoch 9/30
# 60/60 [==============================] - 48s 791ms/step - loss: 0.1978 - accuracy: 0.9300 - val_loss: 0.2152 - val_accuracy: 0.9250
# Epoch 10/30
# 60/60 [==============================] - 53s 884ms/step - loss: 0.2006 - accuracy: 0.9233 - val_loss: 0.1940 - val_accuracy: 0.9333
# Epoch 11/30
# 60/60 [==============================] - 54s 896ms/step - loss: 0.1880 - accuracy: 0.9375 - val_loss: 0.2340 - val_accuracy: 0.9292
# Epoch 12/30
# 60/60 [==============================] - 56s 935ms/step - loss: 0.1563 - accuracy: 0.9367 - val_loss: 0.2018 - val_accuracy: 0.9292
# Epoch 13/30
# 60/60 [==============================] - 52s 864ms/step - loss: 0.1468 - accuracy: 0.9442 - val_loss: 0.1829 - val_accuracy: 0.9333
# Epoch 14/30
# 60/60 [==============================] - 51s 845ms/step - loss: 0.1456 - accuracy: 0.9525 - val_loss: 0.1617 - val_accuracy: 0.9500
# Epoch 15/30
# 60/60 [==============================] - 56s 935ms/step - loss: 0.1318 - accuracy: 0.9533 - val_loss: 0.2790 - val_accuracy: 0.9458
# Epoch 16/30
# 60/60 [==============================] - 52s 861ms/step - loss: 0.1239 - accuracy: 0.9583 - val_loss: 0.1609 - val_accuracy: 0.9500
# Epoch 17/30
# 60/60 [==============================] - 49s 817ms/step - loss: 0.1214 - accuracy: 0.9592 - val_loss: 0.1189 - val_accuracy: 0.9625
# Epoch 18/30
# 60/60 [==============================] - 48s 797ms/step - loss: 0.1021 - accuracy: 0.9625 - val_loss: 0.3229 - val_accuracy: 0.9042
# Epoch 19/30
# 60/60 [==============================] - 49s 808ms/step - loss: 0.0813 - accuracy: 0.9725 - val_loss: 0.3131 - val_accuracy: 0.9375
# Epoch 20/30
# 60/60 [==============================] - 48s 798ms/step - loss: 0.1142 - accuracy: 0.9692 - val_loss: 0.1640 - val_accuracy: 0.9583
# Epoch 21/30
# 60/60 [==============================] - 49s 810ms/step - loss: 0.0896 - accuracy: 0.9675 - val_loss: 0.1837 - val_accuracy: 0.9500
# Epoch 22/30
# 60/60 [==============================] - 49s 812ms/step - loss: 0.1096 - accuracy: 0.9708 - val_loss: 0.1351 - val_accuracy: 0.9458
# Epoch 23/30
# 60/60 [==============================] - 54s 892ms/step - loss: 0.1117 - accuracy: 0.9667 - val_loss: 0.1270 - val_accuracy: 0.9667
# Epoch 24/30
# 60/60 [==============================] - 56s 928ms/step - loss: 0.0655 - accuracy: 0.9775 - val_loss: 0.2180 - val_accuracy: 0.9542
# Epoch 25/30
# 60/60 [==============================] - 52s 858ms/step - loss: 0.0730 - accuracy: 0.9733 - val_loss: 0.1777 - val_accuracy: 0.9625
# Epoch 26/30
# 60/60 [==============================] - 55s 912ms/step - loss: 0.0868 - accuracy: 0.9742 - val_loss: 0.1999 - val_accuracy: 0.9583
# Epoch 27/30
# 60/60 [==============================] - 52s 873ms/step - loss: 0.0716 - accuracy: 0.9750 - val_loss: 0.1183 - val_accuracy: 0.9542
# Epoch 28/30
# 60/60 [==============================] - 55s 902ms/step - loss: 0.0801 - accuracy: 0.9750 - val_loss: 0.1260 - val_accuracy: 0.9667
# Epoch 29/30
# 60/60 [==============================] - 53s 877ms/step - loss: 0.0698 - accuracy: 0.9742 - val_loss: 0.1912 - val_accuracy: 0.9417
# Epoch 30/30
# 60/60 [==============================] - 52s 862ms/step - loss: 0.0614 - accuracy: 0.9800 - val_loss: 0.1670 - val_accuracy: 0.9542

# %% [markdown]
# ### Graphical Representation of our outputs

# %%
HistoryDict = ANN_Model.history

val_losses = HistoryDict["val_loss"]
val_acc = HistoryDict["val_accuracy"]
acc = HistoryDict["accuracy"]
losses = HistoryDict["loss"]
epochs = range(1, len(val_losses)+1)

# %%
plt.plot(ANN_Model.history["accuracy"])
plt.plot(ANN_Model.history["val_accuracy"])
plt.ylabel("ACCURACY")
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.plot(epochs, losses, "k-", label="LOSS")
plt.plot(epochs, val_losses, "ro", label="LOSS VALIDATION")
plt.title("LOSS AND LOSS VAL")
plt.xlabel("EPOCH")
plt.ylabel("LOSS AND LOSS VAL")
plt.legend()
plt.show()

# %%
plt.plot(epochs, acc, "k-", label="ACCURACY")
plt.plot(epochs, val_acc, "ro", label="ACCURACY VALIDATION")
plt.title("ACCURACY & ACCURACY VAL")
plt.xlabel("EPOCH")
plt.ylabel("ACCURACY & ACCURACY VAL")
plt.legend()
plt.show()

# %%
Dict_Summary = pd.DataFrame(ANN_Model.history)
Dict_Summary.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### OUTCOMES OF MODEL

# %%
Model_Results = Model.evaluate(Test_Set, verbose=False)
print("LOSS:  " + "%.4f" % Model_Results[0])
print("ACCURACY:   " + "%.2f" % Model_Results[1])
# Out:
# LOSS:  0.1262
# ACCURACY:   0.97

# %% [markdown]
# ### Prediction Process

# %%
Main_Data_Prediction = pd.DataFrame({"JPG":jpgPath_series})

# %%
print(Main_Data_Prediction.head())
# Out:
#                                    JPG
# 0     brain-tumor-detection\no\no0.jpg
# 1     brain-tumor-detection\no\no1.jpg
# 2    brain-tumor-detection\no\no10.jpg
# 3   brain-tumor-detection\no\no100.jpg
# 4  brain-tumor-detection\no\no1000.jpg

# %%
Main_Test_Generator = ImageDataGenerator(rescale=1./255)

# %%
Main_Test_Set = Main_Test_Generator.flow_from_dataframe(dataframe=Main_Data_Prediction,
                                                       x_col="JPG",
                                                       y_col=None,
                                                       color_mode="grayscale",
                                                        class_mode=None,
                                                        batch_size=20,
                                                        target_size=(200,200))
# Out:
# Found 3000 validated image filenames.

# %%
Model_Test_Prediction = Model.predict(Main_Test_Set)

# %%
Model_Test_Prediction = Model_Test_Prediction.argmax(axis=-1)

# %%
print(Model_Test_Prediction)
# Out:
# [1 0 0 ... 1 1 0]

# %%
Last_Prediction = []

[Last_Prediction.append('No') if i==1 else Last_Prediction.append('Tumor') for i in Model_Test_Prediction]
print(Last_Prediction)
# Out:
# ['No', 'Tumor', 'Tumor', 'Tumor', 'Tumor', 'No', 'Tumor', 'No', 'Tumor', 'No', 'No', 'No', 'Tumor', 'No', 'No', 'Tumor', 'Tumor', 'Tumor', 'No', 'No', 'No', 'Tumor', 'Tumor', 'No', 'No', 'No', 'Tumor', 'Tumor', 'No', 'No', 'No', 'Tumor', 'No', 'No', 'Tumor', 'Tumor', 'No', 'No', 'Tumor', 'No', 'Tumor', 'No', 'No', 'No', 'Tumor', 'No', 'No', 'No', 'No', 'Tumor', 'Tumor', 'No', 'Tumor', 'No', 'Tumor', 'Tumor', 'No', 'No', 'Tumor', 'No', 'Tumor', 'Tumor', 'Tumor', 'Tumor', 'No', 'Tumor', 'No', 'No', 'Tumor', 'Tumor', 'Tumor', 'No', 'Tumor', 'No', 'Tumor', 'No', 'Tumor', 'Tumor', 'No', 'Tumor', 'Tumor', 'No', 'No', 'Tumor', 'No', 'Tumor', 'No', 'No', 'Tumor', 'Tumor', 'No', 'Tumor', 'Tumor', 'Tumor', 'Tumor', 'Tumor', 'Tumor', 'Tumor', 'No', 'No', 'No', 'No', 'No', 'Tumor', 'No', 'No', 'Tumor', 'No', 'No', 'No', 'Tumor', 'No', 'No', 'No', 'Tumor', 'Tumor', 'No', 'No', 'Tumor', 'Tumor', 'No', 'No', 'Tumor', 'No', 'Tumor', 'No', 'Tumor', 'Tumor', 'No', 'No', 'No', 'Tumor', 'No', 'Tumor', 'Tumor', 'Tumor', 'No', 'No', 'Tumor', 'No', 'No', 'No', 'No', 'Tumor', 'No', 'No', 'No', 'No', 'No', 'Tumor', 'No', 'Tumor', 'No', 'No', 'Tumor', 'Tumor', 'No', 'Tumor', 'Tumor', 'Tumor', 'No', 'Tumor', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'Tumor', 'Tumor', 'Tumor', 'No', 'Tumor', 'Tumor', 'No', 'No', 'No', 'Tumor', 'Tumor', 'Tumor', 'No', 'Tumor', 'No', 'No', 'No', 'Tumor', 'Tumor', 'No', 'Tumor', 'Tumor', 'Tumor', 'Tumor', 'No', 'No', 'No', 'Tumor', 'No', 'No', 'No', 'Tumor', 'Tumor', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'Tumor', 'Tumor', 'Tumor', 'No', 'Tumor', 'Tumor', 'Tumor', 'No', 'No', 'Tumor', 'No', 'Tumor', 'Tumor', 'No', 'Tumor', 'Tumor', 'No', 'No', 'No', 'Tumor', 'Tumor', 'No', 'Tumor', 'Tumor', 'No', 'Tumor', 'No', 'No', 'Tumor', 'Tumor', 'Tumor', 'No', 'No', 'Tumor', 'No', 'Tumor', 'Tumor', 'Tumor', 'No', 'No', 'No', 'Tumor', 'No', 'Tumor', 'No', 'No', 'No', 'Tumor', 'Tumor', 'Tumor', 'No', 'No', 'Tumor', 'Tumor', 'Tumor', 'Tumor', 'Tumor', 'Tumor', 'Tumor', 'Tumor', 'No', 'Tumor', 'Tumor', 'No', 'Tumor', 'Tumor', 'No', 'No', 'No', 'Tumor', 'Tumor', 'Tumor', 'Tumor', 'Tumor', 'Tumor', 'No', 'No', 'No', 'No', 'Tumor', 'Tumor', 'Tumor', 'Tumor', 'Tumor', 'Tumor', 'Tumor', 'No', 'Tumor', 'Tumor', 'Tumor', 'No', 'Tumor', 'No', 'No', 'No', 'Tumor', 'No', 'Tumor', 'No', 'No', 'No', 'Tumor', 'Tumor', 'No', 'No', 'No', 'No', 'No', 'Tumor', 'Tumor', 'Tumor', 'Tumor', 'Tumor', 'No', 'Tumor', 'No', 'No', 'No', 'Tumor', 'No', 'Tumor', 'No', 'Tumor', 'No', 'No', 'Tumor', 'Tumor', 'No', 'Tumor', 'No', 'No', 'No', 'No', 'No', 'Tumor', 'Tumor', 'No', 'Tumor', 'No', 'No', 'No', 'No', 'Tumor', 'Tumor', 'No', 'No', 'Tumor', 'Tumor', 'No', 'No', 'Tumor', 'Tumor', 'No', 'No', 'No', 'No', 'Tumor', 'No', 'Tumor', 'Tumor', 'Tumor', 'Tumor', 'Tumor', 'Tumor', 'No', 'No', 'Tumor', 'Tumor', 'Tumor', 'No', 'Tumor', 'No', 'No', 'Tumor', 'Tumor', 'No', 'No', 'No', 'Tumor', 'No', 'Tumor', 'No', 'No', 'No', 'No', 'Tumor', 'No', 'Tumor', 'No', 'No', 'Tumor', 'Tumor', 'Tumor', 'Tumor', 'No', 'No', 'Tumor', 'Tumor', 'Tumor', 'Tumor', 'No', 'Tumor', 'No', 'Tumor', 'Tumor', 'Tumor', 'No', 'Tumor', 'Tumor', 'Tumor', 'Tumor', 'Tumor', 'No', 'Tumor', 'Tumor', 'No', 'No', 'Tumor', 'Tumor', 'Tumor', 'Tumor', 'Tumor', 'No', 'Tumor', 'No', 'Tumor', 'Tumor', 'Tumor', 'No', 'Tumor', 'No', 'No', 'No', 'No', 'Tumor', 'No', 'No', 'No', 'No', 'Tumor', 'No', 'Tumor', 'Tumor', 'No', 'Tumor', 'Tumor', 'Tumor', 'No', 'No', 'Tumor', 'No', 'No', 'No', 'Tumor', 'Tumor', 'Tumor', 'Tumor', 'Tumor', 'No', 'No', 'Tumor', 'No', 'No', 'No', 'No', 'Tumor', 'Tumor', 'No', 'Tumor', 'Tumor', 'Tumor', 'No', 'No', 'No', 'No', 'No', 'Tumor', 'No', 'No', 'Tumor', 'Tumor', 'Tumor', 'Tumor', 'No', 'Tumor', 'Tumor', 'Tumor', 'No', 'Tumor', 'No', 'No', 'Tumor', 'No', 'Tumor', 'No', 'No', 'Tumor', 'Tumor', 'No', 'Tumor', 'No', 'No', 'Tumor', 'No', 'Tumor', 'Tumor', 'No', 'Tumor', 'Tumor', 'No', 'No', 'Tumor', 'Tumor', 'Tumor', 'Tumor', 'No', 'Tumor', 'No', 'No', 'No', 'Tumor', 'Tumor', 'Tumor ...

# %%
fig, axes = plt.subplots(nrows=5,
                        ncols=5,
                        figsize=(20,20),
                        subplot_kw={'xticks': [], 'yticks':[]})
for i, ax in enumerate(axes.flat):
    ax.imshow(plt.imread(Main_Data_Prediction["JPG"].loc[i]))
    ax.set_title(f"Prediction:{Last_Prediction[i]}")
plt.tight_layout()
plt.show()
